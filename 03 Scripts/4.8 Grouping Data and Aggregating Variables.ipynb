# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import data
path = r'C:\Users\nakarton\Downloads\NakartonDataFiles\09.01.24_Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\nakarton\\Downloads\\NakartonDataFiles\\09.01.24_Instacart Basket Analysis'

# %%
# Import orders_products_merged
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
# Creating subset of df_ords_prods_merge
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_previous_order  product_id  add_to_cart_order  reordered  \
# 0                        NaN         196                  1          0
# ...

# %%
# Grouping data with pandas
df.groupby('product_name')

# %%
# Aggregating data with agg()
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Performing multiple aggregation 
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# The subset presents an indepth information about a particular column as seen with the department_id above.

# %%
# Aggregating data with transform() to create loyalty flag
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\nakarton\AppData\Local\Temp\ipykernel_18416\3253460532.py:2: FutureWarning: The provided callable <function amax at 0x0000025EE20A9940> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_previous_order  product_id  add_to_cart_order  reordered  \
# 0                        NaN         196                  1          0
# ...

# %%
df_ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# ..       ...      ...           ...                 ...                ...
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
# ...

# %%
pd.options.display.max_rows = None

# %%
# df_ords_prods_merge.head(100)

# %%
# Deriving column with loc() to create loyalty flag
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# df_ords_prods_merge.head(60)

# %%
# Accessing specific columns
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
# Aggregating loyalty flag by prices to check spending habits
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
# The New Customer average price is $3 more than that of a Loyal Customer.

# %%
# Determine the mean product price of every user with transform()
df_ords_prods_merge['mean_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\nakarton\AppData\Local\Temp\ipykernel_18416\3449771300.py:2: FutureWarning: The provided callable <function mean at 0x0000025EE20AA660> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_ords_prods_merge['mean_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Create spending flag column using loc() 
df_ords_prods_merge.loc[df_ords_prods_merge['mean_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['mean_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Print spending flag frequency
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'mean_product_price', 'spending_flag']].head(10)
# Out:
#    user_id  mean_product_price spending_flag
# 0        1            6.367797   Low spender
# 1        1            6.367797   Low spender
# 2        1            6.367797   Low spender
# 3        1            6.367797   Low spender
# 4        1            6.367797   Low spender
# 5        1            6.367797   Low spender
# 6        1            6.367797   Low spender
# 7        1            6.367797   Low spender
# 8        1            6.367797   Low spender
# 9        1            6.367797   Low spender

# %%
# Use groupby and transform to create median days orders column 
df_ords_prods_merge['median_days_between_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_previous_order'].transform(np.median)
# Out:
# C:\Users\nakarton\AppData\Local\Temp\ipykernel_18416\3171447476.py:2: FutureWarning: The provided callable <function median at 0x0000025EE21EBF60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_ords_prods_merge['median_days_between_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_previous_order'].transform(np.median)

# %%
df_ords_prods_merge[['user_id', 'days_since_previous_order', 'median_days_between_orders']].head(15)
# Out:
#     user_id  days_since_previous_order  median_days_between_orders
# 0         1                        NaN                        20.5
# 1         1                       15.0                        20.5
# 2         1                       21.0                        20.5
# 3         1                       29.0                        20.5
# 4         1                       28.0                        20.5
# 5         1                       19.0                        20.5
# 6         1                       20.0                        20.5
# 7         1                       14.0                        20.5
# 8         1                        0.0                        20.5
# 9         1                       30.0                        20.5
# 10       15                        7.0                        10.0
# 11       15                        8.0                        10.0
# 12       15                        7.0                        10.0
# ...

# %%
# Create frequency flag using loc
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['median_days_between_orders'] <= 20) & (df_ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
df_ords_prods_merge['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# nan                             5
# Name: count, dtype: int64

# %%
# View relevant columns
df_ords_prods_merge[['user_id', 'days_since_previous_order', 'median_days_between_orders', 'order_frequency']].head(30)
# Out:
#     user_id  days_since_previous_order  median_days_between_orders  \
# 0         1                        NaN                        20.5
# 1         1                       15.0                        20.5
# 2         1                       21.0                        20.5
# 3         1                       29.0                        20.5
# 4         1                       28.0                        20.5
# 5         1                       19.0                        20.5
# 6         1                       20.0                        20.5
# 7         1                       14.0                        20.5
# 8         1                        0.0                        20.5
# 9         1                       30.0                        20.5
# 10       15                        7.0                        10.0
# 11       15                        8.0                        10.0
# 12       15                        7.0                        10.0
# ...

# %%
# Export dataframe to pickle
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_grouped.pkl'))
