# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import data
path = r'C:\Users\nakarton\Downloads\NakartonDataFiles\09.01.24_Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\nakarton\\Downloads\\NakartonDataFiles\\09.01.24_Instacart Basket Analysis'

# %%
# Import df_ords original data
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
# Import df_prods original data
df_prods = pd.read_csv(r'C:\Users\nakarton\Downloads\NakartonDataFiles\09.01.24_Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
# Import df_dep_t_new Prepared Data
df_dep_t_new = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'), index_col = False)

# %%
# Import df_ords Prepared Data
df_ords = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
# Consistency check df_prods
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
# Finding missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# df_prods Product_name median (Median cannot be imputed here because they are strings)
df_prods['product_name'].fillna('median value', inplace=True)

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
# df_prods mixed type data
for col in df_prods.columns.tolist():
 weird = (df_prods[[col]].map(type) != df_prods[[col]].iloc[0].apply(type)).any(axis = 1)
if len (df_prods[weird]) > 0:
 print (col)

# %%
# df_prods clean
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49693, 5)

# %%
# df_prods duplicate
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# Addressing duplicates
df_prods_clean.shape
# Out:
# (49693, 5)

# %%
# Dropping duplcates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49688, 5)

# %%
# Consistency check df_ords
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
# df_ords min and max - The 'unnamed' and 'order_id' for both 'min' and 'max' are almost similar. This is also the case with 'std', 'mean', '25%', '50%' and '75%'.

# %%
# df_ords mixed type data (No mixed types)
for col in df_ords.columns.tolist():
 weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
if len (df_ords[weird]) > 0:
 print (col)

# %%
# Finding missing values
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_nan
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 11               11   2168274        2    prior             1
# 26               26   1374495        3    prior             1
# 39               39   3343014        4    prior             1
# 45               45   2717275        5    prior             1
# ...             ...       ...      ...      ...           ...
# 3420930     3420930    969311   206205    prior             1
# 3420934     3420934   3189322   206206    prior             1
# 3421002     3421002   2166133   206207    prior             1
# 3421019     3421019   2227043   206208    prior             1
# 3421069     3421069   3154581   206209    prior             1
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# 11                        2                 11                     NaN
# ...

# %%
# Comment - The missing values here are in the days_since_prior_order column. The count 206209 rows.

# %%
# df_ords clean
df_ords_clean = df_ords[df_ords['days_since_prior_order'].isnull() == False]

# %%
df_ords_clean.shape
# Out:
# (3214874, 8)

# %%
df_ords_clean = df_ords

# %%
df_ords_clean['new_customer'] = df_ords['days_since_prior_order'].isnull() == True

# %%
df_ords_clean
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     NaN
# 1                         3                  7                    15.0
# ...

# %%
# df_ords duplicate
df_dups = df_ords_clean[df_ords_clean.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, new_customer]
# Index: []

# %%
# Dropping duplcates
df_ords_clean_no_dups = df_ords_clean.drop_duplicates()

# %%
df_ords_clean_no_dups
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     NaN
# 1                         3                  7                    15.0
# ...

# %%
# Comment - I find this method more convenient.

# %%
# Export your df_ords dataframe as “orders_checked.csv”
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checked.csv'))

# %%
# Export your df_prods dataframe as “products_checked.csv”
df_prods.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))
